# %% [markdown]
# # Course Overview
#
# In a nutshell, **Intro to Python for Data Science** will teach you how to get started with Python, use python to analyze your custom data, and apply simple machine learning using supporting packages. This course cover, but not limited to:
#
# 1. Python Basics <br>
#   1.1 Python for simple calculation <br>
#   1.2 Data types in python <br>
#   1.3 Data structures in python <br>
#   1.4 Control flow
# 2. Modular Python <br>
#   2.1 Functions and Methods <br>
#   2.2 Built-in function and methods <br>
#   2.3 Scripting in Python
# 3. Data Analysis <br>
#   3.1 Get started with Numpy and Pandas <br>
#   3.2 Simple Exploratory Data Analysis (EDA) <br>
#   3.3 Build Data Analysis Report
# 4. Data Science and Machine Learning <br>
#   4.1 Intro to Data Science and Machine Learning <br>
#   4.2 Get started with Scikit-learn <br>
#   4.3 Deep Learning and Tensorflow overview <br>
#   4.4 Build Data Science Project
#
# ## Prerequisites
#
# Before we dive into those stuffs, we have something to prepare first. We have to create our **environment/workflow** such that it can boost our learning process instead of figuring why it works in mine but not in yours.
#
# 0. Workflow Setup and Configuration <br>
#   0.1 Download [Anaconda](https://www.anaconda.com/distribution/#download-section) and install it <br>
#   0.2 Download [Git Bash](https://git-scm.com/download/win) and install it (too) <br>
#   0.3 Download [Visual Studio Code](https://code.visualstudio.com/download) and (of course) install it <br>
#   0.3 Shell workshop (Optional) - Could be done in the first week or later
#
# ## Motivation on Python for Data Science
#
# > "Data! Data! Data!" he cried impatiently. "I can't make bricks without clay." - **Arthur Conan Doyle**
#
# Data is ubiquitous and we live in this kind of world. From websites, smartphones, apps, they all have our data. They know us better than ourselves. Probably, they drive us to do something, not otherwise. Buried in these data are answers to countless questions that no one's ever thought to ask.
#
# ## Defining Data Science
#
# Many people have their own definition. Also, there's a statement stating that **data scientist is someone who knows more statistics than a computer scientist and more computer science than a statistician.** Well, some people think it's a joke. Let's define ours:
#
# > Data science is a process of extracting insights from messy data. Then, data scientist is the executor.
#
# ## Python: A Readable Programming Language
#
# Python is authored by [Guido van Rossum](https://en.wikipedia.org/wiki/Guido_van_Rossum) and releasing its initial version back in February 1991. Currently, the latest version of Python is 3.7.4. Earlier version of Python, which is 2.7, won't be maintained past 2020 ([see here](https://www.python.org/dev/peps/pep-0373/)).
#
# Things you should keep in mind while coding in Python:
# 1. Python is case-sensitive
# 2. Spacing is important
# 3. Watch out for error message (will help you learn too)
#
# **Python is used for general programming**, meaning it's used for not only data science things, but also web development, etc. Python somewhat has a [Zen](https://www.python.org/dev/peps/pep-0020/) description of its design principles. Code written in this *python style* is often described as **Pythonic** way of coding.

# %% [markdown]
# ## The Zen of Python, by Tim Peters
#
# ```
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# ```

# %% [markdown]
# ## History of Python
#
# As previously mentioned, python has its own journey from 1991 until now. Below are a viz of timeline of python.
#
# ![](https://media.geeksforgeeks.org/wp-content/uploads/20190502023317/TIMELINE.jpg)
# <i><center>image from <a href="https://www.geeksforgeeks.org/history-of-python/">geeksforgeeks</a></center></i>
#
# ## Future of Python
#
# No need for words, just look at these graphics.
#
# ![](https://149351115.v2.pressablecdn.com/wp-content/uploads/2017/09/growth_major_languages-1-1400x1200.png)
# <i><center>growth of python by <a href="https://stackoverflow.blog/2017/09/06/incredible-growth-python/">stackoverflow</a></center></i>
#
# ![](https://149351115.v2.pressablecdn.com/wp-content/uploads/2017/09/projections-1-1400x1200.png)
# <i><center>future projection by <a href="https://stackoverflow.blog/2017/09/06/incredible-growth-python/">stackoverflow</a></center></i>
